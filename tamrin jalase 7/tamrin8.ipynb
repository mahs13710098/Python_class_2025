# %%
def sorted_unique_nums(lst1):
    n = list(set([lst2[i] for lst2 in lst1 for i in range(len(lst2))]))
    n.sort(reverse=True)
    return n

# %%
nested_list = [[1, 2, 3], [2, 3, 4], [3, 4, 5]]
a = sorted_unique_nums(nested_list)
a
# Out:
# [5, 4, 3, 2, 1]
