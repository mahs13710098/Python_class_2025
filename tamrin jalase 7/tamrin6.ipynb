# %%
def fillNone(lst):
    for item in lst:
        if item == None:
            if lst.index(item) == 0:
                lst[0]=0
            else:
               lst[lst.index(item)]  = lst[lst.index(item)-1]
    return lst

# %%
#lst[lst.index(item)] 
a = [1,None,2,None,4,None,4,5,None] 
b = fillNone(a)
b
# Out:
# [1, 1, 2, 2, 4, 4, 4, 5, 5]
