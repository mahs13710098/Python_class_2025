# %%
def rate_control(v):
    if v <= 70:
        return 'good'
    neg_poan = int((v - 70)/5)
    if neg_poan < 12:
        return -neg_poan
    return 'Your certificate is invalid.'

# %%
a = rate_control(60)
b = rate_control(90)
c = rate_control(140)
a,b,c
# Out:
# ('good', -4, 'Your certificate is invalid.')
