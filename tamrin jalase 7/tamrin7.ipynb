# %%
def people_less25(lst):
   lst2 = [dict for dict in lst if dict['age']>25]
   return lst2

# %%
people = [{"name": "Ali", "age": 23},{"name": "Mina", "age": 30},{"name": "Reza", "age": 25},{"name": "Sara", "age": 28}]
lst = people_less25(people)
lst
# Out:
# [{'name': 'Mina', 'age': 30}, {'name': 'Sara', 'age': 28}]
