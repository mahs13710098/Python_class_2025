# %%
list_1 = ['milk', 'suger', 'butter', 'yogurt', 'cheese']
list_2 = [5, 2, 10, 1, 3]
p = dict(zip(list_1,list_2))
maximum = max(p.values())
minimum = min(p.values())
print(p)
print(f'maximum of dictionary p is {maximum}')
print(f'minimum of dictionary p is {minimum}')
# Out:
# {'milk': 5, 'suger': 2, 'butter': 10, 'yogurt': 1, 'cheese': 3}
# maximum of dictionary p is 10
# minimum of dictionary p is 1
