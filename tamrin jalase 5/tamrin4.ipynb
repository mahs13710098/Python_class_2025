# %%
lis = []
k = int(input('please enter the length of your list'))
for _ in range(k):
    j = input('please enter a string or number')
    lis.append(j)
for i in lis:
    if lis.count(i) > 1:
        for m in range(lis.count(i)-1):
            lis.remove(i)
lis
# Out:
# ['a', 'f', 'k', 'o']
