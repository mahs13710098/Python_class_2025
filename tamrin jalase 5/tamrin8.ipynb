# %%
strr = input('please enter a string : ')
lst1 = ['e','i','o','a','u']
str2=''
for char in strr:
    if char in lst1 and char not in str2:
        str2 += char
list(str2)
# Out:
# ['o', 'i', 'e', 'a', 'u']
