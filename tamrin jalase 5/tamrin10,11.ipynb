# %%
import random
s = ['hello', 'mello', 'yello', 'hallo']
list=[]
ind_list=[]
for _ in range(100):
        list.append(random.choices(s)[0])
print(list)
for p in s[1:]:
        for _ in range(list.count(p)):
                list.remove(p)
print(list)
# Out:
# ['hallo', 'yello', 'mello', 'mello', 'mello', 'hello', 'hallo', 'hallo', 'hello', 'hello', 'yello', 'mello', 'hello', 'mello', 'mello', 'hallo', 'hello', 'hello', 'yello', 'hello', 'hello', 'hallo', 'hello', 'hello', 'hallo', 'hallo', 'hello', 'mello', 'yello', 'hallo', 'yello', 'hello', 'hallo', 'mello', 'hello', 'hallo', 'mello', 'hallo', 'mello', 'yello', 'mello', 'hallo', 'yello', 'hello', 'yello', 'hello', 'hello', 'yello', 'hallo', 'yello', 'hello', 'yello', 'mello', 'hello', 'hello', 'hello', 'hello', 'yello', 'hello', 'hello', 'hello', 'yello', 'yello', 'yello', 'yello', 'hello', 'yello', 'hallo', 'yello', 'yello', 'mello', 'hello', 'hallo', 'hallo', 'hallo', 'yello', 'hello', 'mello', 'yello', 'mello', 'yello', 'mello', 'yello', 'mello', 'hello', 'yello', 'hallo', 'hello', 'mello', 'mello', 'yello', 'mello', 'yello', 'hallo', 'hello', 'hallo', 'hello', 'hello', 'hallo', 'hello']
# ...
