# %%
num = input('please enter an integer number: ')
if num[0] in ["+", "-"]:
    if num[1:].isdigit():
        num = int(num)
        rem = num%2
        if rem == 0:
            print('the integer number that you entered is even')
        else:
            print('the integer number that you entered is odd')
    else:
        print('the number you entered is not integer,please try again')
else:
    if num.isdigit():
        num = int(num)
        rem = num%2
        if rem == 0:
            print('the integer number that you entered is even')
        else:
            print('the integer number that you entered is odd')
    else:
         print('the number you entered is not integer,please try again')
# Out:
# the integer number that you entered is odd
