# %%
num = input('please enter an integer number: ')
s = 1
if num[0] in ["+", "-"]:
    if num[1:].isdigit():
        num = int(num)  
        if num > 0:
            for j in range(abs(num)):
                s = s*(j+1)
            print(f'the Factorial of {num} is {s} ')    
        elif num < 0:
            print(f'the Factorial of {num} is not defined ') 
        else:
             print('the Factorial of 0 is 1 ')
    else:
        print('the number you entered is not integer,please try again')
elif num.isdigit():
    num = int(num)
    if num > 0:
        for j in range(abs(num)):
            s = s*(j+1)
        print(f'the Factorial of {num} is {s} ')    
    elif num < 0:
        print(f'the Factorial of {num} is not defined ') 
    else:
        print('the Factorial of 0 is 1 ')
else:
    print('the number you entered is not integer,please try again')
# Out:
# the Factorial of 5 is 120
