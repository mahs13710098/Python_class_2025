# %%
num = float(input('please enter a number: '))
minimum = num
maximum = num
for i in range(9):
    num = float(input('please enter a number: '))
    if num > maximum:
        maximum = num
    elif num < minimum:
        minimum = num
print(f'maximum is {maximum}')
print(f'minimum is {minimum}')
# Out:
# maximum is 10.0
# minimum is 1.0
