# %%
p=1
for i in range(10):
    num = input('please enter a number :')
    if num[0] in ["+", "-"]:
        if num[1:].isdigit():
            p = p*int(num)
        else:
            print('the number you entered is not integer,please run again')
    elif num.isdigit():
        p = p*int(num)
    else:
        print('the number you entered is not integer,please run again')
print(p)
# Out:
# -1024
