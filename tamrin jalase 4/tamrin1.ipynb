# %%
namee = 'mahsa bagheri'
#slicing
print(namee[::-1])
#using loop1
s2=''
for i in namee:
    s2 =i + s2 
print(s2)
#using loop2
s=''
for i in range(len(namee)-1,-1,-1):
    s = s + namee[i]
print(s)
# Out:
# irehgab asham
# irehgab asham
# irehgab asham
